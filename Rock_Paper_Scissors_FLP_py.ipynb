# %% [markdown]
# <a href="https://colab.research.google.com/github/CliffAD/Machine-Learning-Fun-Level-Projects/blob/main/Rock_Paper_Scissors_FLP_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Author : Clifford Anthony Dsouza")
print("Fun level Projects - Rock Paper Scissors")

# %%
import random

# %%
def play_game():
    # Define the valid choices
    choices = ["Rock", "Paper", "Scissors"]

    print("Welcome to the Rock-Paper-Scissors Game!")
    print("Type 'Quit' to stop playing.\n")

# %%
while True:
        # Get user input
        user_input = input("Enter Rock, Paper, or Scissors: ").capitalize()
# Out:
# Enter Rock, Paper, or Scissors: rock
# Enter Rock, Paper, or Scissors: Paper
# Enter Rock, Paper, or Scissors: Scissor
# Enter Rock, Paper, or Scissors: rock
# Enter Rock, Paper, or Scissors: rock
# Enter Rock, Paper, or Scissors: rock

# %%
# Check if user wants to quit
        if user_input == 'Quit':
            print("Thanks for playing! Goodbye.")
            break

# %%
# Validate user input
        if user_input not in choices:
            print("Invalid choice! Please try again.\n")
            continue

# %%
# Generate computer choice
        computer_choice = random.choice(choices)

        print(f"\nYou chose: {user_input}")
        print(f"Computer chose: {computer_choice}")

# %%
# Determine the winner
        if user_input == computer_choice:
            print("Result: It's a tie!")
        elif (user_input == "Rock" and computer_choice == "Scissors") or \
             (user_input == "Paper" and computer_choice == "Rock") or \
             (user_input == "Scissors" and computer_choice == "Paper"):
            print("Result: You win! 🎉")
        else:
            print("Result: Computer wins! 🤖")

        print("-" * 30 + "\n")

if __name__ == "__main__":
    play_game()
